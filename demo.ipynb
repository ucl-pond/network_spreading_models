# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.linalg import expm
from code.network_diffusion_model import NDM, FKPP

# %%
x_0 = np.zeros(84)
x_0[5] = 1
t = [0,10,100]
ndm = NDM("data/tractography.csv", 0.1, t, x_0, ["Bankssts_L"])

C = ndm.prep_connectome()
sns.heatmap(C)
# Out:
# <Axes: >

# %% [markdown]
# ## !! TO DO: Stuck at get_initial_conditions

# %%
# x = ndm.run_NDM()
# plt.figure()
# plt.plot(t, x.T)
